# %%
# ! pip install -r ../../../../requirements.txt -U

# %%
# from agent_framework.azure import AzureAIAgentClient
# from agent_framework import ChatAgent, HostedWebSearchTool

# from azure.ai.projects.aio import AIProjectClient
# from azure.ai.agents.models import BingGroundingTool
# from azure.identity.aio import AzureCliCredential

import asyncio
import os

from agent_framework.azure import AzureAIAgentClient, AzureAIAgentsProvider
from azure.identity.aio import AzureCliCredential

# %%
import os
import base64
from dotenv import load_dotenv

# %%
load_dotenv("../../../../.env")
# Out:
# True

# %%
AgentName = "Search-Agent"
AgentInstructions = """You are a helpful assistant that can search the web for current information.
            Use the Bing search tool to find up-to-date information and provide accurate, well-sourced answers.
            Always cite your sources when possible."""

# %%
async with (
        AzureCliCredential() as credential,
        AzureAIAgentsProvider(credential=credential) as provider,
    ):
        client = AzureAIAgentClient(credential=credential)
        # Create Bing Grounding search tool using instance method
        # The connection ID will be automatically picked up from environment variable
        bing_search_tool = client.get_web_search_tool()

        agent = await provider.create_agent(
            name= AgentName,
            instructions= AgentInstructions,
            model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"], 
            tools=[bing_search_tool],
        )

        query = "What is today's date and weather in Guangzhou?"
        print(f"User: {query}")
        result = await agent.run(query)
        print(f"Result: {result}\n")
# Out:
# User: What is today's date and weather in Guangzhou?
# Result: Today's date is February 27, 2026.
#
# The current weather in Guangzhou is partly sunny with a temperature of around 82°F (28°C), feeling like 85°F (29°C). The forecast for today includes some clouds with occasional passing showers. The temperature is expected to vary between 77°F and 72°F. Winds are mild at about 6 mph coming from the south. The humidity is at 58%, creating warm and humid conditions. There is some chance of rain throughout the day, with passing showers expected in the afternoon and evening.
#
# So, today is warm and humid with some rain and clouds expected in Guangzhou. If you plan to be outdoors, carrying an umbrella might be a good idea to stay dry during the passing showers【4:0†source】【4:1†source】【4:3†source】.
