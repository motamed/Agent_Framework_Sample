# %%
# ✅ Dependencies installed via terminal:
# uv venv .venv --python 3.13
# uv pip install ipykernel --python .venv/Scripts/python.exe
# uv pip install -r Installation/requirements.txt --python .venv/Scripts/python.exe
#
# Select the .venv kernel in VS Code to use these packages.

# %%
import os
from agent_framework import Agent
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential

# %%
import os
import base64
from dotenv import load_dotenv

# %%
from dotenv import find_dotenv
load_dotenv(find_dotenv())
# Out:
# True

# %%
AgentName = "Search-Agent"
AgentInstructions = """You are a helpful assistant that can search the web for current information.
            Use the Bing search tool to find up-to-date information and provide accurate, well-sourced answers.
            Always cite your sources when possible."""

# %%
client = FoundryChatClient(credential=AzureCliCredential())
bing_search_tool = client.get_web_search_tool()

agent = Agent(
    client=client,
    name=AgentName,
    instructions=AgentInstructions,
    tools=[bing_search_tool],
)

query = "What is today's date and weather in Guangzhou?"
print(f"User: {query}")
result = await agent.run(query)
print(f"Result: {result}\n")
# Out:
# User: What is today's date and weather in Guangzhou?
# Result: Today's date is March 27, 2026.
#
# The weather in Guangzhou today is cloudy with a high temperature of around 32°C and a low of about 24°C at night. It will be breezy with average wind speeds of about 21 km/h from the south-southeast. There is no significant chance of rain today. Humidity is around 56%, and the weather alert indicates a thunder warning for the day.
#
# Sunrise was at approximately 06:24 AM, and sunset will be around 06:41 PM.
#
# If you need more detailed hourly forecasts or specific weather data, please let me know!
#
# Sources:
# - EaseWeather: https://www.easeweather.com/asia/china/guangdong/guangzhou-shi/guangzhou/today
# - Weather Atlas: https://www.weather-atlas.com/en/china/guangzhou
