# %% [markdown]
# # 🚀 Create Your First AI Agent - Travel Planning Assistant (Python)
#
# ## 📋 Tutorial Overview
#
# Welcome to your first hands-on experience building an AI agent with the Microsoft Agent Framework! This tutorial will guide you through creating a sophisticated travel planning assistant that can automatically generate personalized vacation itineraries using Azure OpenAI.
#
# **What You'll Build:**
# - 🎯 **Smart Travel Agent**: An AI assistant that plans detailed day trips
# - 🎲 **Random Destination Tool**: Custom function for inspiring destination suggestions
# - 🤖 **Conversational Interface**: Natural language interaction with advanced AI capabilities
# - 🔧 **Tool Integration**: Learn how agents use functions to extend their capabilities
#
# ## 🎯 Learning Objectives
#
# By completing this tutorial, you will understand:
#
# ### 🏗️ **Agent Architecture Fundamentals**
# - How to structure AI agents using the Microsoft Agent Framework
# - The relationship between agents, tools, and language models
# - Best practices for agent configuration and deployment
#
# ### 🛠️ **Tool Integration Patterns**
# - Creating custom functions that agents can call dynamically
# - Understanding function calling in large language models
# - Designing tools for optimal agent performance
#
# ### 🔗 **API Integration Strategies**
# - Connecting to Azure OpenAI for enterprise-grade AI inference
# - Managing API credentials and configuration securely
# - Handling asynchronous operations in agent workflows
#
# ### 💡 **Conversation Management**
# - Building natural, contextual conversations with AI agents
# - Managing conversation state and memory
# - Implementing effective agent instructions and personality
#
# ## ⚙️ Prerequisites & Environment Setup
#
# ### 📦 **Required Dependencies**
#
# First, ensure you have the latest Agent Framework installed:
#
# ```bash
# pip install agent-framework-core -U
# ```
#
# ### 🔑 **Azure OpenAI Configuration**
#
# You'll need an Azure OpenAI resource:
#
# 1. **Create Azure OpenAI Resource**: Deploy an OpenAI resource in your Azure subscription
# 2. **Deploy a Model**: Deploy a model such as gpt-4o-mini
# 3. **Configure Environment Variables**: Create a `.env` file in your project root:
#
# ```env
# # Azure OpenAI Configuration
# AZURE_OPENAI_ENDPOINT=https://your-resource.openai.azure.com/
# AZURE_OPENAI_CHAT_DEPLOYMENT_NAME=gpt-4o-mini
# AZURE_OPENAI_API_KEY=your_azure_openai_api_key
# AZURE_OPENAI_API_VERSION=2024-12-01-preview
# ```
#
# ### 🏢 **Enterprise Considerations**
#
# - **Security**: Store API keys in environment variables, never in source code
# - **Rate Limits**: Azure OpenAI has usage quotas; monitor your consumption
# - **Model Selection**: Choose appropriate models based on your use case and budget
# - **Error Handling**: Implement robust error handling for production deployments
#
# ## 🎨 Design Pattern: Function-Calling Agents
#
# This tutorial demonstrates the **Function-Calling Agent** pattern, where:
#
# ```mermaid
# graph LR
#     A[User Request] --> B[Agent Analysis]
#     B --> C{Need Tools?}
#     C -->|Yes| D[Call Function]
#     C -->|No| E[Direct Response]
#     D --> F[Process Results]
#     F --> E
#     E --> G[Final Response]
# ```
#
# **Key Benefits:**
# - 🎯 **Deterministic Actions**: Tools provide reliable, predictable functionality
# - 🔧 **Extensibility**: Easy to add new capabilities without retraining
# - 🏢 **Enterprise Ready**: Integrate with existing systems and databases
# - 📊 **Observability**: Clear tracking of agent decisions and tool usage
#
# ## 🌟 Next Steps
#
# After completing this tutorial, explore:
# - **Advanced Tool Patterns**: Database queries, API integrations, file operations
# - **Multi-Agent Systems**: Coordinating multiple specialized agents
# - **RAG Integration**: Adding knowledge retrieval capabilities
# - **Production Deployment**: Scaling agents for enterprise use
#
# Let's build your first AI agent! 🚀

# %%
# ✅ Dependencies installed via terminal:
# uv venv .venv --python 3.13
# uv pip install ipykernel --python .venv/Scripts/python.exe
# uv pip install -r Installation/requirements.txt --python .venv/Scripts/python.exe
#
# Select the .venv kernel in VS Code to use these packages.

# %%
# 📦 Import Essential Libraries
# Core system and utility libraries for building AI agents

import os                      # Environment variable access for secure configuration
from random import randint     # Random number generation for destination selection

# 🔧 Environment configuration management
from dotenv import load_dotenv # Load API keys and settings from .env file

# %%
# 🤖 Import Microsoft Agent Framework Components
from agent_framework import Agent
from agent_framework.openai import OpenAIChatCompletionClient

# %%
# 🔧 Load Environment Configuration
from dotenv import find_dotenv
load_dotenv(find_dotenv())
# Out:
# True

# %%
# 🎯 Define Agent Tool: Random Destination Generator
# This function becomes a callable tool that the agent can use dynamically

def get_random_destination() -> str:
    """
    🌍 Generate Random Travel Destination
    
    Provides the agent with the ability to suggest exciting vacation destinations
    when users need inspiration for their travel plans.
    
    Returns:
        str: A randomly selected destination from our curated global list
        
    Enterprise Note: In production, this could be enhanced with:
    - Database integration for dynamic destination management
    - Personalization based on user preferences and history
    - Real-time availability and pricing data integration
    """
    # 🗺️ Curated list of world-class vacation destinations
    # Each destination offers unique cultural, natural, or urban experiences
    destinations = [
        "Barcelona, Spain",        # Mediterranean culture & architecture
        "Paris, France",           # European elegance & romance
        "Berlin, Germany",         # Modern history & vibrant arts scene
        "Tokyo, Japan",            # Cutting-edge technology & tradition
        "Sydney, Australia",       # Iconic harbors & outdoor lifestyle
        "New York, USA",           # Urban energy & cultural diversity
        "Cairo, Egypt",            # Ancient history & archaeological wonders
        "Cape Town, South Africa", # Stunning landscapes & wine regions
        "Rio de Janeiro, Brazil",  # Beaches, mountains & carnival culture
        "Bali, Indonesia"          # Tropical paradise & spiritual retreats
    ]
    
    # 🎲 Return randomly selected destination for inspiring travel planning
    return destinations[randint(0, len(destinations) - 1)]

# %%
# 🔗 Create Azure OpenAI Chat Client
openai_chat_client = OpenAIChatCompletionClient(
    azure_endpoint=os.environ.get("AZURE_OPENAI_ENDPOINT"),
    model=os.environ.get("AZURE_OPENAI_CHAT_DEPLOYMENT_NAME"),
    api_key=os.environ.get("AZURE_OPENAI_API_KEY"),
    api_version=os.environ.get("AZURE_OPENAI_API_VERSION"),
)

# %%
# 🤖 Create Your First AI Agent!
# This is where the magic happens - creating an intelligent travel planning assistant

agent = Agent(
    client=openai_chat_client,  # 🔗 AI model connection
    instructions="You are a helpful AI Agent that can help plan vacations for customers at random destinations.",  # 🎯 Agent personality and role
    tools=[get_random_destination]   # 🛠️ Available functions the agent can use
)

# %%
# 🚀 Test Your Agent - Request a Travel Plan
# Let's see your agent in action! It will automatically use the random destination tool
response = await agent.run("Plan me a day trip")

# %%
# 🔍 Explore the Response Structure
# Examine the complete response object to understand how agent conversations work
# This shows the internal structure, including messages and metadata
response

# %%
# 📖 Extract and Display Your Travel Plan
# Get the agent's response and display it in a user-friendly format

# Extract the agent's latest response message
last_message = response.messages[-1]
# Get the text content of the message
text_content = last_message.contents[0].text

# 🎉 Display your personalized travel itinerary!
print("✈️ Your AI-Generated Travel Plan:")
print("=" * 50)
print(text_content)
print("=" * 50)
print("🤖 Created by your AI Travel Agent using Microsoft Agent Framework!")
# Out:
# ✈️ Your AI-Generated Travel Plan:
# ==================================================
# Great choice: New York, USA. Here’s a one-day, low-backtracking itinerary that hits iconic sights, good food, and great skyline views. I’ve included transit tips and swaps so you can tailor it on the fly.
#
# Morning (Upper Manhattan → Midtown)
# - 8:30–9:15 AM | Coffee + pastry
#   - Levain Bakery (Upper West Side, near 72 St) or Angelina Paris by Bryant Park if you want to start in Midtown.
# - 9:30–10:45 AM | Central Park highlights
#   - Enter at 72nd St; see Strawberry Fields, Bow Bridge, Bethesda Terrace, The Lake. Optional: rent bikes near Columbus Circle if you prefer to cover more.
# - 11:00 AM–12:30 PM | Culture pick (choose one, short visit)
#   - The Met (Upper East Side, 82nd St): art masterworks; suggested 60–90 mins in the highlights.
#   - OR American Museum of Natural History (Upper West Side): dinosaur halls and blue whale.
#   - If you prefer to skip a museum, head straight down Fifth Avenue: St. Patrick’s Cathedral, Rockefeller Center.
#
# Lunch + Midtown Icons
# - 12:45–1:45 PM | Lunch near Bryant Park/Rockefeller Center
#   - Quick bites: Urbanspace 45th, Los Tacos No. 1, Joe’s Pizza, Dig.
#   - Sit-down: The Smith (near Bryant Park), Parker & Quinn.
# - 2:00–3:00 PM | Observation deck or Midtown stroll
#   - Top of the Rock (great view of Central Park) or skip the deck and explore Rockefeller Center, Radio City, Times Square (15–20 mins is enough).
#
# Afternoon (Chelsea/West Side)
# - 3:15–4:45 PM | High Line + Chelsea Market
#   - Subway: from Rockefeller Center (B/D/F/M) to 14 St, or walk/ride Citi Bike.
#   - Stroll the High Line (Gansevoort St to 23–30th St). Dip into Chelsea Market for snacks (Doughnuttery, Very Fresh Noodles) or coffee.
#
# Late Afternoon into Sunset (Downtown or Hudson Yards)
# Option A: Downtown + Ferry
# - 5:15–6:00 PM | 9/11 Memorial (free outdoor pools; contemplative stop).
# - 6:15–7:15 PM | Staten Island Ferry round trip (free). Great skyline and Statue views; aim for golden hour/sunset.
#
# Option B: Hudson Yards
# - 5:15–6:15 PM | Hudson Yards and The Edge (if you skipped Top of the Rock and want a deck with a glass floor).
# - Or browse shops and grab a pre-dinner drink.
#
# Evening (Brooklyn or Theater District)
# Option A: Brooklyn Bridge + DUMBO
# - 7:30–8:15 PM | Walk the Brooklyn Bridge from Manhattan (City Hall side) into Brooklyn.
# - 8:15–9:30 PM | Dinner in DUMBO: Juliana’s (pizza), Cecconi’s, Time Out Market food hall. Post-dinner skyline photos at Pebble Beach/Empire Fulton Ferry.
#
# Option B: Midtown show + late bite
# - 7:00–10:00 PM | Broadway show (book in advance; TKTS booth in Times Square offers day-of discounts).
# - 10:15 PM | Late-night eats: The Lambs Club bar, Iván Ramen Slurp Shop (Hell’s Kitchen), or a classic slice at Prince Street Pizza (NoMad outpost).
#
# Getting Around
# - Subway: $2.90/ride; tap contactless (OMNY). Google Maps/Citymapper for routes. For this plan, expect 5–7 rides total if you don’t walk/bike much.
# - Walking: Manhattan is walkable; bring comfortable shoes.
# - Rideshare/Taxi: Useful late night or if pressed for time.
# - Citi Bike: Good for park and West Side; day pass available.
#
# Rough Timing and Flow Tips
# - If you do a museum + an observation deck, keep each to about an hour to avoid rushing.
# - Choose either Top of the Rock or The Edge—doing both in one day can feel redundant.
# - Ferry timing: Check sunset time; aim to board 15–20 minutes before for upper-deck views.
#
# Budget Notes
# - Free/low-cost: Central Park, High Line, 9/11 Memorial grounds, Staten Island Ferry, Brooklyn Bridge.
# - Tickets to consider: Observation deck ($40–$50), museum entry (Met has pay-what-you-wish for NY/NJ/CT residents; otherwise ~$30).
# - Food range: $5–$6 for a slice, $10–$20 for fast-casual, $25–$40+ for sit-down dinner.
#
# Weather Swaps
# - Rainy/cold: Spend more time at The Met/MoMA, Grand Central Terminal (and its market), New York Public Library, Chelsea Market, and the Oculus at World Trade Center.
# - Hot/sunny: Prioritize early Central Park, indoor midday museum, late-day ferry/bridge when cooler.
#
# Want me to tailor this? Tell me:
# - Date/season and day of week
# - Interests (art, food, views, shopping, history, with kids, etc.)
# - Pace (packed vs relaxed), budget, and any mobility considerations
# - Preference for a single neighborhood focus vs highlights across the city
# ==================================================
# 🤖 Created by your AI Travel Agent using Microsoft Agent Framework!
